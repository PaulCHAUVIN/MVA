# %%
! git clone https://github.com/lychengr3x/Bird-Species-Classification-Using-Transfer-Learning.git
# !cd Bird-Species-Classification-Using-Transfer-Learning/dataset
# !wget http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# !tar xvzf CUB_200_2011.tgz
# !rm CUB_200_2011.tgz
# %matplotlib notebook
import torch
import matplotlib.pyplot as plt
from data import BirdsDataset
from argument import Args
from model import VGG16Transfer, ClassificationStatsManager, Resnet18Transfer
import nntools as nt
from utils import imshow, plot
# Out:
# fatal: destination path 'Bird-Species-Classification-Using-Transfer-Learning' already exists and is not an empty directory.
# --2022-11-29 17:30:28--  http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz
# Resolving www.vision.caltech.edu (www.vision.caltech.edu)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to www.vision.caltech.edu (www.vision.caltech.edu)|185.199.108.153|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-11-29 17:30:28 ERROR 404: Not Found.
#
# tar (child): CUB_200_2011.tgz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# rm: cannot remove 'CUB_200_2011.tgz': No such file or directory
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-001c9d3ca682> in <module>
#       7 import torch
#       8 import matplotlib.pyplot as plt
# ----> 9 from data import BirdsDataset
#      10 from argument import Args
#      11 from model import VGG16Transfer, ClassificationStatsManager, Resnet18Transfer
#
# ModuleNotFoundError: No module named 'data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
args = Args()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f533d406ed70> in <module>
# ----> 1 args = Args()
#
# NameError: name 'Args' is not defined

# %%
vars(args)

# %%
args.plot=True

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_set = BirdsDataset(args.root_dir, image_size=args.image_size)
val_set = BirdsDataset(args.root_dir, mode='val',
                       image_size=args.image_size)
num_classes = train_set.number_of_classes()

if args.model == 'vgg':
    net = VGG16Transfer(num_classes)
else:
    net = Resnet18Transfer(num_classes)
net = net.to(device)
adam = torch.optim.Adam(net.parameters(), lr=args.lr)
stats_manager = ClassificationStatsManager()
exp = nt.Experiment(net, train_set, val_set, adam, stats_manager, batch_size=args.batch_size,
                    output_dir=args.output_dir, perform_validation_during_training=True)

if args.plot:
    fig, axes = plt.subplots(ncols=2, figsize=(7, 3))
    exp.run(num_epochs=args.num_epochs,
            plot=lambda exp: plot(exp, fig=fig, axes=axes))
else:
    exp.run(num_epochs=args.num_epochs)
